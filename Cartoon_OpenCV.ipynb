# %% [markdown]
# <a href="https://colab.research.google.com/github/dedemasutti/AI-projects/blob/master/Cartoon_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread(r'imagem_02.jpg')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray = cv2.medianBlur(gray,5)
edges = cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,9,9)

# %%
color = cv2.bilateralFilter(img,9,250,250)
cartoon = cv2.bitwise_and(color,color, mask=edges)

# %%
cv2_imshow(img)
cv2_imshow(edges)
cv2_imshow(cartoon)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=714x952 at 0x7F39F9875390>
# <PIL.Image.Image image mode=L size=714x952 at 0x7F39FFA62DD0>
# <PIL.Image.Image image mode=RGB size=714x952 at 0x7F39FFA62590>
